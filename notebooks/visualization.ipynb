# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas
import os

# %% [markdown]
# ## Visualization for IMDB-Binary

# %%
imdb_binary = os.path.join('../data/', 'IMDB-BINARY')

imdb_binary_A = os.path.join(imdb_binary, 'IMDB-BINARY_A.txt')
imdb_binary_A_data = pandas.read_csv(imdb_binary_A, sep='\t', header=None)

imdb_binary_graph1_edge = imdb_binary_A_data[:292]
imdb_binary_graph1_edge.columns = ['edge']
imdb_binary_graph1_edge['edge'] = imdb_binary_graph1_edge['edge'].str.split(', ')
imdb_binary_graph1_edge
# Out:
# /tmp/ipykernel_824/2611594256.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_binary_graph1_edge['edge'] = imdb_binary_graph1_edge['edge'].str.split(', ')
#          edge
# 0      [1, 3]
# 1      [3, 1]
# 2      [1, 5]
# 3      [5, 1]
# 4      [1, 6]
# ..        ...
# 287  [17, 20]
# 288  [20, 18]
# 289  [18, 20]
# 290  [20, 19]
# 291  [19, 20]
#
# [292 rows x 1 columns]

# %%
# create a graph
imdb_binary_graph1 = nx.Graph()

# # add nodes
# for i in range(20):
#     imdb_binary_graph1.add_node(i)

# add edges
for i in range(292):
    imdb_binary_graph1.add_edge(imdb_binary_graph1_edge['edge'][i][0], imdb_binary_graph1_edge['edge'][i][1])

# %%
# draw the graph
nx.draw(imdb_binary_graph1, with_labels=True)  
plt.title('IMDB-BINARY Graph 1')
plt.show()

# %%
imdb_binary_graph2_edge = imdb_binary_A_data[292:804]
imdb_binary_graph2_edge.columns = ['edge']
imdb_binary_graph2_edge['edge'] = imdb_binary_graph2_edge['edge'].str.split(', ')
imdb_binary_graph2_edge
# Out:
# /tmp/ipykernel_824/1903546009.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_binary_graph2_edge['edge'] = imdb_binary_graph2_edge['edge'].str.split(', ')
#          edge
# 292  [21, 27]
# 293  [27, 21]
# 294  [21, 28]
# 295  [28, 21]
# 296  [21, 35]
# ..        ...
# 799  [36, 52]
# 800  [52, 40]
# 801  [40, 52]
# 802  [52, 44]
# 803  [44, 52]
#
# [512 rows x 1 columns]

# %%
imdb_binary_graph2 = nx.Graph()

for i in range(292, 804):
    imdb_binary_graph2.add_edge(imdb_binary_graph2_edge['edge'][i][0], imdb_binary_graph2_edge['edge'][i][1])

nx.draw(imdb_binary_graph2, with_labels=True)
plt.title('IMDB-BINARY Graph 2')
plt.show()

# %% [markdown]
# ## Visualization for IMDB-Multi

# %%
imdb_multi = os.path.join('../data/', 'IMDB-MULTI')
imdb_multi_A = os.path.join(imdb_multi, 'IMDB-MULTI_A.txt')
imdb_multi_A_data = pandas.read_csv(imdb_multi_A, sep='\t', header=None)

# %%
imdb_multi_graph1_edge = imdb_multi_A_data[:84]
imdb_multi_graph1_edge.columns = ['edge']
imdb_multi_graph1_edge['edge'] = imdb_multi_graph1_edge['edge'].str.split(', ')
imdb_multi_graph1_edge
# Out:
# /tmp/ipykernel_824/3789722714.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_multi_graph1_edge['edge'] = imdb_multi_graph1_edge['edge'].str.split(', ')
#       edge
# 0   [1, 2]
# 1   [2, 1]
# 2   [1, 3]
# 3   [3, 1]
# 4   [1, 4]
# ..     ...
# 79  [4, 7]
# 80  [7, 5]
# 81  [5, 7]
# 82  [7, 6]
# 83  [6, 7]
#
# [84 rows x 1 columns]

# %%
imdb_multi_graph1 = nx.Graph()

for i in range(84):
    imdb_multi_graph1.add_edge(imdb_multi_graph1_edge['edge'][i][0], imdb_multi_graph1_edge['edge'][i][1])

nx.draw(imdb_multi_graph1, with_labels=True)
plt.title('IMDB-MULTI Graph 1')
plt.show()

# %%
imdb_multi_graph2_edge = imdb_multi_A_data[84:252]
imdb_multi_graph2_edge.columns = ['edge']
imdb_multi_graph2_edge['edge'] = imdb_multi_graph2_edge['edge'].str.split(', ')
imdb_multi_graph2_edge

imdb_multi_graph2 = nx.Graph()

for i in range(84, 168):
    imdb_multi_graph2.add_edge(imdb_multi_graph2_edge['edge'][i][0], imdb_multi_graph2_edge['edge'][i][1])

nx.draw(imdb_multi_graph2, with_labels=True)
plt.title('IMDB-MULTI Graph 2')
plt.show()
# Out:
# /tmp/ipykernel_824/697991087.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_multi_graph2_edge['edge'] = imdb_multi_graph2_edge['edge'].str.split(', ')

# %% [markdown]
# ## Visualization for MUTAG

# %%
mutag = os.path.join('../data/', 'MUTAG')

mutag_A = os.path.join(mutag, 'MUTAG_A.txt')
mutag_A_data = pandas.read_csv(mutag_A, sep='\t', header=None)

mutag_graph1_edge = mutag_A_data[:38]
mutag_graph1_edge.columns = ['edge']
mutag_graph1_edge['edge'] = mutag_graph1_edge['edge'].str.split(', ')
mutag_graph1_edge

mutag_graph1 = nx.Graph()

for i in range(38):
    mutag_graph1.add_edge(mutag_graph1_edge['edge'][i][0], mutag_graph1_edge['edge'][i][1])

nx.draw(mutag_graph1, with_labels=True)
plt.title('MUTAG Graph 1')
plt.show()
# Out:
# /tmp/ipykernel_824/508245030.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutag_graph1_edge['edge'] = mutag_graph1_edge['edge'].str.split(', ')

# %%
mutag_graph2_edge = mutag_A_data[38:66]
mutag_graph2_edge.columns = ['edge']
mutag_graph2_edge['edge'] = mutag_graph2_edge['edge'].str.split(', ')
mutag_graph2_edge

mutag_graph2 = nx.Graph()

for i in range(38, 66):
    mutag_graph2.add_edge(mutag_graph2_edge['edge'][i][0], mutag_graph2_edge['edge'][i][1])

nx.draw(mutag_graph2, with_labels=True)
plt.title('MUTAG Graph 2')
plt.show()
# Out:
# /tmp/ipykernel_824/3545547238.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mutag_graph2_edge['edge'] = mutag_graph2_edge['edge'].str.split(', ')
